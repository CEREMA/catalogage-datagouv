# %%
import pandas as pd

import requests
import pandas as pd
import time

# %%
# !pip install sentence-transformers pyyaml

import yaml
import numpy as np
from sentence_transformers import SentenceTransformer, util
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.6/739.6 kB 68.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 793.2/793.2 kB 72.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/4.5 MB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 95.0 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/11.7 MB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 98.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 94.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/526.6 MB ? eta -:--:--
#    ━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/526.6 MB 115.6 MB/s eta 0:00:05
#    ━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/526.6 MB 114.6 MB/s eta 0:00:05
#    ━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.0/526.6 MB 114.8 MB/s eta 0:00:04
#    ━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.3/526.6 MB 114.9 MB/s eta 0:00:04
# ...

# %%
def load_categories(path="categories.yaml"):
    with open(path, "r", encoding="utf-8") as f:
        cats = yaml.safe_load(f)

    flat = []  # liste plate (catégorie, sous-catégorie, texte de référence)
    for cat in cats:
        for sub in cat.get("subcategories", []):
            flat.append({
                "category": cat["slug"],
                "subcategory": sub["slug"],
                "label": f"{cat['label']} > {sub['label']}",
                "text": f"{cat['description']}. {sub['description']}",
            })
    return flat

# %%
def classify_df(df, categories_path="categories.yaml",
                 model_name="paraphrase-multilingual-mpnet-base-v2",
                 threshold=0.25):
    model = SentenceTransformer(model_name)
    cats = load_categories(categories_path)

    # Embeddings des catégories (une seule fois)
    cat_texts = [c["text"] for c in cats]
    cat_embeddings = model.encode(cat_texts, convert_to_tensor=True)

    # Embeddings des datasets (titre + description + tags)
    doc_texts = (
        df["title"].fillna("") + ". " +
        df["description"].fillna("") + ". " +
        df["tags"].apply(lambda t: " ".join(t) if isinstance(t, list) else "")
    ).tolist()
    doc_embeddings = model.encode(doc_texts, convert_to_tensor=True,
                                   batch_size=64, show_progress_bar=True)

    # Similarité cosinus dataset x catégorie
    sims = util.cos_sim(doc_embeddings, cat_embeddings).cpu().numpy()

    best_idx = sims.argmax(axis=1)
    best_score = sims.max(axis=1)

    df = df.copy()
    df["category"] = [cats[i]["category"] if s >= threshold else "" for i, s in zip(best_idx, best_score)]
    df["subcategory"] = [cats[i]["subcategory"] if s >= threshold else "" for i, s in zip(best_idx, best_score)]
    df["category_score"] = best_score
    return df

# %%
df=pd.read_parquet('datagouvds2.parquet')

# %%
df.head()
# Out:
#                           id  \
# 0   6a826c488feaf1584f1dba40
# 7   6a7faceb92d679122704ef32
# 12  6a7f1d71f5a0602f732de662
# 13  6a7f1b68be6d17e8334d6314
# 20  6a7e87b12d75648c1e04ef1d
#
#                                                 title  \
# 0   Recueils des actes administratifs des préfectures
# 7           Horaires de passage théoriques aux arrêts
# 12  Mobilité- Stationnement des parkings en temps ...
# 13  Voirie - Places handicapées GIG / GIC - Grand ...
# 20          Réglementation de boisement - PUY-DE-DÔME
#
#                                                  slug acronym  \
# 0   recueils-des-actes-administratifs-des-prefectures     RAA
# 7         horaires-de-passage-theoriques-aux-arrets-3    None
# 12  mobilite-stationnement-des-parkings-en-temps-reel    None
# 13  voirie-places-handicapees-gig-gic-grand-poitie...    None
# 20          reglementation-de-boisement-puy-de-dome-2    None
#
#                                                   url  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'title', 'slug', 'acronym', 'url', 'organization',
#        'organization_id', 'owner', 'owner_id', 'description',
#        'description_short', 'frequency', 'license', 'temporal_coverage.start',
#        'temporal_coverage.end', 'spatial.granularity', 'spatial.zones',
#        'spatial.geom', 'featured', 'created_at', 'last_modified', 'badges',
#        'tags', 'archived', 'resources_count', 'main_resources_count',
#        'resources_formats', 'harvest.backend', 'harvest.domain',
#        'harvest.remote_id', 'harvest.remote_url', 'harvest.uri',
#        'harvest.created_at', 'harvest.issued_at', 'harvest.modified_at',
#        'harvest.last_update', 'harvest.dct_identifier', 'quality_score',
#        'metric.discussions', 'metric.discussions_open', 'metric.reuses',
#        'metric.reuses_by_months', 'metric.dataservices', 'metric.followers',
#        'metric.followers_by_months', 'metric.views',
#        'metric.resources_downloads'],
#       dtype='object')

# %%
df=df[['id', 'title', 'slug', 'acronym', 'url', 'organization',
       'organization_id', 'description',
       'description_short', 'frequency', 'temporal_coverage.start',
       'temporal_coverage.end', 'spatial.granularity', 'spatial.zones',
       'spatial.geom', 'featured', 'created_at', 'last_modified', 'badges',
       'tags']]

# %%
categories_path="catalogue_datamobilitev2.yaml"
model_name="paraphrase-multilingual-mpnet-base-v2"

# %%
model = SentenceTransformer(model_name)
cats = load_categories(categories_path)
# Out:
# ...
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 4229.69it/s]

# %%
# il faudrait ajouter dans load_categories une catégorie "main cat" ; pour l'instant la fonction ne lit que les sous-catégorie, pas la catégorie principale

# %%
cat_texts = [c["text"] for c in cats]
cat_embeddings = model.encode(cat_texts, convert_to_tensor=True)
# Embeddings des datasets (titre + description + tags)
doc_texts = (
    df["title"].fillna("") + ". " +
    df["description"].fillna("") + ". " +
    df["tags"].apply(lambda t: " ".join(t) if isinstance(t, list) else "")
).tolist()
doc_embeddings = model.encode(doc_texts, convert_to_tensor=True,
                               batch_size=64, show_progress_bar=True)
# Similarité cosinus dataset x catégorie
sims = util.cos_sim(doc_embeddings, cat_embeddings).cpu().numpy()
# Out:
# ...
# Batches: 100%|██████████| 252/252 [25:06<00:00,  5.98s/it]

# %%
sims[1,53]
# Out:
# np.float32(0.45947495)

# %%
cats[53]["subcategory"]
# Out:
# 'capteurs_trafic'

# %%
for i in range(54):
    df[cats[i]["subcategory"]]=sims[:,i]
# Out:
# /tmp/ipykernel_708/3633769785.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[cats[i]["subcategory"]]=sims[:,i]
# /tmp/ipykernel_708/3633769785.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[cats[i]["subcategory"]]=sims[:,i]
# /tmp/ipykernel_708/3633769785.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
sims[:,1]
# Out:
# array([0.23944542, 0.34592405, 0.463405  , ..., 0.23749605, 0.44149452,
#        0.29337776], shape=(16123,), dtype=float32)

# %%
df.columns
# Out:
# Index(['id', 'title', 'slug', 'acronym', 'url', 'organization',
#        'organization_id', 'description', 'description_short', 'frequency',
#        'temporal_coverage.start', 'temporal_coverage.end',
#        'spatial.granularity', 'spatial.zones', 'spatial.geom', 'featured',
#        'created_at', 'last_modified', 'badges', 'tags', 'stationnement_voirie',
#        'aires_stationnement', 'parcs_enclos_ouvrage',
#        'stationnement_residentiel', 'stationnement_velo',
#        'recharge_electrique_stationnement', 'tarification_stationnement',
#        'usage_stationnement', 'donnees_socioeco_stationnement',
#        'offre_theorique_tc', 'info_temps_reel_tc',
#        'tarification_billettique_tc', 'accessibilite_tc', 'qualite_service_tc',
#        'usage_frequentation_tc', 'infrastructure_materiel_tc',
#        'transport_scolaire', 'donnees_financieres_tc', 'lineaire_voirie',
#        'description_surfacique_voirie', 'etat_chaussee', 'signalisation',
# ...

# %%
df.to_csv('testcat.csv')
